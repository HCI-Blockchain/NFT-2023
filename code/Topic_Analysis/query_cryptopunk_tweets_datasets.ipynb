# %% [markdown]
# # install snscrape packages

# %%
# !pip3 install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import snscrape.modules.twitter

# %% [markdown]
# # query #stopasianhate tweets

# %%
# Creating list to append tweet data to
tweets_list = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#Cryptopunks since:2022-01-15 until:2022-02-15 min_faves:3 exclude:retweets','corona lang:en').get_items()):
    tweets_list.append([tweet.date,  tweet.content]) #tweet.id
tweets_list
# Out:
# [[datetime.datetime(2022, 2, 14, 23, 42, 41, tzinfo=datetime.timezone.utc),
#   'In the words of KDANYE our vision is KRYSTAL KLEAR. Our $KDA god blessed us with kadonda #kadena #cryptopunks \n\nCan we get a UHHHHHHHH drop us a UHHHHHH in our discord sers: https://t.co/NWpJ7erDMH\n\nhttps://t.co/lfuWI7jSm9'],
#  [datetime.datetime(2022, 2, 14, 23, 32, 29, tzinfo=datetime.timezone.utc),
#   'My crypto crazy collection is in @opensea \nThis is not a #BoredApe nor a #cryptopunks but this collection will explode your heart 💓\n\nhttps://t.co/z0L3A9uzwA\n #NFTCommumity #NFT #nfts #NFTGiveaway #nftcollector #nftart #cryptoart #cryptoartist https://t.co/2ZQA2RAosT'],
#  [datetime.datetime(2022, 2, 14, 23, 22, 49, tzinfo=datetime.timezone.utc),
#   'Highest-ever #cryptopunks  sale nets $24 million \nhttps://t.co/a4HGy43xV8 #cryptocurrency #NFT #NFTs #XDOGE'],
#  [datetime.datetime(2022, 2, 14, 23, 13, 4, tzinfo=datetime.timezone.utc),
# ...

# %%
result= pd.DataFrame(tweets_list, columns=['Date', 'Tweets'])
result
# Out:
#                           Date  \
# 0    2022-02-14 23:42:41+00:00
# 1    2022-02-14 23:32:29+00:00
# 2    2022-02-14 23:22:49+00:00
# 3    2022-02-14 23:13:04+00:00
# 4    2022-02-14 22:56:55+00:00
# ...                        ...
# 2941 2022-01-15 01:30:21+00:00
# 2942 2022-01-15 00:52:36+00:00
# 2943 2022-01-15 00:14:53+00:00
# 2944 2022-01-15 00:10:48+00:00
# 2945 2022-01-15 00:02:55+00:00
#
#                                                  Tweets
# 0     In the words of KDANYE our vision is KRYSTAL K...
# 1     My crypto crazy collection is in @opensea \nTh...
# 2     Highest-ever #cryptopunks  sale nets $24 milli...
# 3     2 NFTs Used as Collateral for $3M Loan on DeFi...
# 4     Which is your favorite @AdamListerArt Studio P...
# ...                                                 ...
# 2941  Mr. Gary Vee buys Cryptoskull for 100 ETH. Pro...
# 2942  Check out this item on OpenSea \n#cryptopunks ...
# 2943  Punk 441 bought for 59.95 ETH ($197,936.91 USD...
# ...

# %%
result.to_csv("queried_tweets_data.csv")

# %% [markdown]
# # query #blacklivesmatter tweets
