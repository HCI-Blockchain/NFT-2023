# %%
import plotly.express as px
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cryptopunks_gender_skintone_info.csv')

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#       date  from    to  eth_price  punk_id   type  gender skin_tone  \
# 0   4/6/19   336  4411      31.00        1  Human    Male      Dark
# 1  7/13/17   166  4540       0.90       14  Human  Female      Dark
# 2  7/17/17  4540  5394       1.85       14  Human  Female      Dark
# 3  12/7/18  5394   204       2.50       14  Human  Female      Dark
# 4   2/1/21   166  5853      20.00       53  Human  Female     Light
#
#    attr_count                                attributes skin_tone_color  \
# 0           2                       ['Smile', 'Mohawk']         #A4031F
# 1           3  ['Pipe', 'Pilot Helmet', 'Hot Lipstick']         #A4031F
# 2           3  ['Pipe', 'Pilot Helmet', 'Hot Lipstick']         #A4031F
# 3           3  ['Pipe', 'Pilot Helmet', 'Hot Lipstick']         #A4031F
# 4           2           ['Big Shades', 'Straight Hair']         #F2A359
#
#                                              img_url
# 0  https://www.larvalabs.com/cryptopunks/cryptopu...
# 1  https://www.larvalabs.com/cryptopunks/cryptopu...
# 2  https://www.larvalabs.com/cryptopunks/cryptopu...
# 3  https://www.larvalabs.com/cryptopunks/cryptopu...
# 4  https://www.larvalabs.com/cryptopunks/cryptopu...

# %%
df['date'] = pd.to_datetime(df['date'], utc=True)

df['date'] = df['date'].apply(lambda x: x.replace(tzinfo=None))

df['dte'] = pd.to_datetime(df['date'])

# set time column as index
df = df.set_index('date')

# sort dataframe by index (i.e., by time) in ascending order
df = df.sort_index()

# %%
df = df.reset_index()

# %%
df
# Out:
#             date  from    to  eth_price  punk_id   type  gender skin_tone  \
# 0     2017-06-23  1406   888       0.20     4641  Human  Female     Light
# 1     2017-06-23  1406  1218       0.04     5719  Human  Female    Medium
# 2     2017-06-23  1406  1218       0.06     6208  Human    Male    Medium
# 3     2017-06-23   166  4722       0.10     5056  Human    Male    Albino
# 4     2017-06-23  1406  2518       0.20     5545  Human  Female    Albino
# ...          ...   ...   ...        ...      ...    ...     ...       ...
# 17821 2022-07-26  3002  1044      94.90     5600  Human    Male    Albino
# 17822 2022-07-26  5318  4950      69.00     4430  Human  Female    Albino
# 17823 2022-07-26   980  1939      94.00     9099  Human    Male     Light
# 17824 2022-07-27  3096  1028      69.69     6221  Human  Female      Dark
# 17825 2022-07-27   402  1955     104.95     2567  Human    Male     Light
#
#        attr_count                                         attributes  \
# 0               3  ['Purple Eye Shadow', 'Wild Blonde', 'Cigarette']
# 1               3      ['Welding Goggles', 'Dark Hair', 'Cigarette']
# 2               2                        ['Shadow Beard', 'Earring']
# 3               4     ['Beanie', 'Luxurious Beard', 'Earring', 'VR']
# 4               5  ['Vape', 'Hot Lipstick', 'Wild Hair', 'Earring...
# ...           ...                                                ...
# 17821           3      ['Frumpy Hair', 'Gold Chain', 'Small Shades']
# 17822           2                ['Clown Eyes Green', 'Frumpy Hair']
# 17823           4  ['Cigarette', 'Mustache', 'Earring', 'Crazy Ha...
# 17824           4  ['Green Eye Shadow', 'Half Shaved', 'Earring',...
# 17825           3                ['Cigarette', 'Fedora', 'Mustache']
#
#       skin_tone_color                                            img_url  \
# 0             #F2A359  https://www.larvalabs.com/cryptopunks/cryptopu...
# 1             #DB9065  https://www.larvalabs.com/cryptopunks/cryptopu...
# 2             #DB9065  https://www.larvalabs.com/cryptopunks/cryptopu...
# 3             #F2DC5D  https://www.larvalabs.com/cryptopunks/cryptopu...
# 4             #F2DC5D  https://www.larvalabs.com/cryptopunks/cryptopu...
# ...               ...                                                ...
# 17821         #F2DC5D  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17822         #F2DC5D  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17823         #F2A359  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17824         #A4031F  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17825         #F2A359  https://www.larvalabs.com/cryptopunks/cryptopu...
#
#              dte
# 0     2017-06-23
# 1     2017-06-23
# 2     2017-06-23
# 3     2017-06-23
# 4     2017-06-23
# ...          ...
# 17821 2022-07-26
# 17822 2022-07-26
# 17823 2022-07-26
# 17824 2022-07-27
# 17825 2022-07-27
#
# [17826 rows x 13 columns]

# %%
# drop rows with duplicate names
df = df.drop_duplicates(subset=['img_url'])

# display the updated dataframe
df
# Out:
#             date  from    to  eth_price  punk_id   type  gender skin_tone  \
# 0     2017-06-23  1406   888       0.20     4641  Human  Female     Light
# 1     2017-06-23  1406  1218       0.04     5719  Human  Female    Medium
# 2     2017-06-23  1406  1218       0.06     6208  Human    Male    Medium
# 3     2017-06-23   166  4722       0.10     5056  Human    Male    Albino
# 4     2017-06-23  1406  2518       0.20     5545  Human  Female    Albino
# ...          ...   ...   ...        ...      ...    ...     ...       ...
# 17778 2022-07-17  2292  2070      88.88     4656  Human  Female    Medium
# 17780 2022-07-17  5496  3096      85.00     4739  Human    Male      Dark
# 17788 2022-07-18   107  1044      84.00     4569  Human    Male     Light
# 17810 2022-07-21   244   801      86.68     4755  Human    Male      Dark
# 17814 2022-07-23    10  1618     110.00     9544  Human  Female     Light
#
#        attr_count                                         attributes  \
# 0               3  ['Purple Eye Shadow', 'Wild Blonde', 'Cigarette']
# 1               3      ['Welding Goggles', 'Dark Hair', 'Cigarette']
# 2               2                        ['Shadow Beard', 'Earring']
# 3               4     ['Beanie', 'Luxurious Beard', 'Earring', 'VR']
# 4               5  ['Vape', 'Hot Lipstick', 'Wild Hair', 'Earring...
# ...           ...                                                ...
# 17778           2                 ['Blonde Short', 'Classic Shades']
# 17780           2                       ['Chinstrap', 'Mohawk Dark']
# 17788           3      ['Clown Eyes Blue', 'Shadow Beard', 'Mohawk']
# 17810           3          ['Messy Hair', 'Earring', 'Normal Beard']
# 17814           3  ['Pipe', 'Straight Hair Blonde', 'Purple Lipst...
#
#       skin_tone_color                                            img_url  \
# 0             #F2A359  https://www.larvalabs.com/cryptopunks/cryptopu...
# 1             #DB9065  https://www.larvalabs.com/cryptopunks/cryptopu...
# 2             #DB9065  https://www.larvalabs.com/cryptopunks/cryptopu...
# 3             #F2DC5D  https://www.larvalabs.com/cryptopunks/cryptopu...
# 4             #F2DC5D  https://www.larvalabs.com/cryptopunks/cryptopu...
# ...               ...                                                ...
# 17778         #DB9065  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17780         #A4031F  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17788         #F2A359  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17810         #A4031F  https://www.larvalabs.com/cryptopunks/cryptopu...
# 17814         #F2A359  https://www.larvalabs.com/cryptopunks/cryptopu...
#
#              dte
# 0     2017-06-23
# 1     2017-06-23
# 2     2017-06-23
# 3     2017-06-23
# 4     2017-06-23
# ...          ...
# 17778 2022-07-17
# 17780 2022-07-17
# 17788 2022-07-18
# 17810 2022-07-21
# 17814 2022-07-23
#
# [6275 rows x 13 columns]

# %%
# replace "Non-human" values in the "skin_tone" column with their corresponding value in the "type" column
df.loc[df['skin_tone'] == 'Non-human', 'skin_tone'] = df['type']

# print the modified dataframe
df.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         date  from    to  eth_price  punk_id   type  gender skin_tone  \
# 0 2017-06-23  1406   888       0.20     4641  Human  Female     Light
# 1 2017-06-23  1406  1218       0.04     5719  Human  Female    Medium
# 2 2017-06-23  1406  1218       0.06     6208  Human    Male    Medium
# 3 2017-06-23   166  4722       0.10     5056  Human    Male    Albino
# 4 2017-06-23  1406  2518       0.20     5545  Human  Female    Albino
#
#    attr_count                                         attributes  \
# 0           3  ['Purple Eye Shadow', 'Wild Blonde', 'Cigarette']
# 1           3      ['Welding Goggles', 'Dark Hair', 'Cigarette']
# 2           2                        ['Shadow Beard', 'Earring']
# 3           4     ['Beanie', 'Luxurious Beard', 'Earring', 'VR']
# 4           5  ['Vape', 'Hot Lipstick', 'Wild Hair', 'Earring...
#
#   skin_tone_color                                            img_url  \
# 0         #F2A359  https://www.larvalabs.com/cryptopunks/cryptopu...
# 1         #DB9065  https://www.larvalabs.com/cryptopunks/cryptopu...
# 2         #DB9065  https://www.larvalabs.com/cryptopunks/cryptopu...
# 3         #F2DC5D  https://www.larvalabs.com/cryptopunks/cryptopu...
# 4         #F2DC5D  https://www.larvalabs.com/cryptopunks/cryptopu...
#
#          dte
# 0 2017-06-23
# 1 2017-06-23
# 2 2017-06-23
# 3 2017-06-23
# 4 2017-06-23

# %%
df_gs = df[['gender','skin_tone']]
df_gs.head()
# Out:
#    gender skin_tone
# 0  Female     Light
# 1  Female    Medium
# 2    Male    Medium
# 3    Male    Albino
# 4  Female    Albino

# %%
pivot_df = df_gs.pivot_table(index='gender', columns='skin_tone', aggfunc=len)

# %%
# add a row and column for total numbers
pivot_df.loc['Total'] = pivot_df.sum()
pivot_df['Total'] = pivot_df.sum(axis=1)

# add a row and column for proportion of each gender and skin tone
total_num = pivot_df.loc['Total', 'Total']

# %%
pivot_df = pivot_df.fillna(0)

# %%
# calculate the total number of observations
total = 6275

# calculate the proportion of each cell
pivot_df_prop = pivot_df / total * 100

# %%
pivot_df
# Out:
# skin_tone  Albino  Alien   Ape    Dark   Light  Medium  Zombie   Total
# gender
# Female      207.0    0.0   0.0   650.0   644.0   701.0     0.0  2202.0
# Male        371.0    2.0  14.0  1166.0  1249.0  1236.0    35.0  4073.0
# Total       578.0    2.0  14.0  1816.0  1893.0  1937.0    35.0  6275.0

# %%
# create the heatmap graph
fig = px.imshow(pivot_df_prop.values,
                labels=dict(x="Skin Tone", y="Gender"),
                x=list(pivot_df_prop.columns),
                y=list(pivot_df_prop.index),
                color_continuous_scale='blues')

# add the corresponding values to each cell of the heatmap
for i in range(len(pivot_df_prop.index)):
    for j in range(len(pivot_df_prop.columns)):
        value = pivot_df_prop.values[i][j]
        count = pivot_df.values[i][j]
        font_size = 14
        font_color = 'black'
        if count > 2000:
            font_color = 'white'
        fig.add_annotation(x=j, y=i, text=f"{format(int(count), ',')}<br>({value:.1f}%)",
                           font=dict(size=font_size, color=font_color),
                           showarrow=False)

# add a title to the graph
fig.update_layout(title='CryptoPunks Gender and Skin Tone Distribution Heatmap')

# show the graph
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f4a03274-d0e3-431d-8bf9-58e7edf98a33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4a03274-d0e3-431d-8bf9-58e7edf98a33")) {                    Plotly.newPlot(                        "f4a03274-d0e3-431d-8bf9-58e7edf98a33",                        [{"coloraxis":"coloraxis","name":"0","x":["Albino","Alien","Ape","Dark","Light","Medium","Zombie","Total"],"y":["Female","Male","Total"],"z":[[3.298804780876494,0.0,0.0,10.358565737051793,10.262948207171315,11.171314741035857,0.0,35.091633466135455],[5.912350597609562,0.03187250996015936,0.22310756972111553,18.58167330677291,19.904382470119522,19.697211155378486,0.5577689243027889,64.90836653386454],[9.211155378486056,0.03187250996015936,0.22310756972111553,28.9402390438247,30.16733067729084,30.868525896414344,0.5577689243027889,100.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Skin Tone: %{x}<br>Gender: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcont ...

# %%
# create the heatmap graph
fig = px.imshow(pivot_df.values,
                labels=dict(x="Skin Tone", y="Gender"),
                x=list(pivot_df.columns),
                y=list(pivot_df.index),
                color_continuous_scale='blues')

# add the corresponding values to each cell of the heatmap
for i in range(len(pivot_df.index)):
    for j in range(len(pivot_df.columns)):
        value = pivot_df.values[i][j]
        font_size = 14
        font_color = 'black'
        if value > 1000:
            font_color = 'white'
        fig.add_annotation(x=j, y=i, text=format(int(value), ','), 
                           showarrow=False, 
                           font=dict(size=font_size, color=font_color))

# add a title to the graph
fig.update_layout(title='CryptoPunks Gender and Skin Tone Distribution Heatmap')

# show the graph
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0c12e392-a101-47aa-b6f3-e9089af9e686" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c12e392-a101-47aa-b6f3-e9089af9e686")) {                    Plotly.newPlot(                        "0c12e392-a101-47aa-b6f3-e9089af9e686",                        [{"coloraxis":"coloraxis","name":"0","x":["Albino","Alien","Ape","Dark","Light","Medium","Zombie"],"y":["Female","Male"],"z":[[207.0,0.0,0.0,650.0,644.0,701.0,0.0],[371.0,2.0,14.0,1166.0,1249.0,1236.0,35.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Skin Tone: %{x}<br>Gender: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth": ...
